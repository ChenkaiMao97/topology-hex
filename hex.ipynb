# %%
# %%bash
# source activate mp
#
# # old parameter:
# # arr=("167"  # r_air
# #      "140"  # r_cen
# #      "4100" # n_back_amor
# #      "3300" # n_cen_amor
# #      "4100" # n_back_crys
# #      "5100" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # two material:
# # arr=("220"  # r_air
# #      "120"  # r_cen
# #      "4980" # n_back_amor
# #      "3578" # n_cen_amor
# #      "3887" # n_back_crys
# #      "6325" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # do a center frequency and spread!!!!!!!!!
# # one material GST326: 3.578 - 6.325:
# #              GSST:   3.33 - 5.1
# center=4100
# diff=200
# arr=("220"  # r_air
#      "120"  # r_cen
#      "$((center + diff))" # n_back_1
#      "$((center - 2*diff))" # n_cen_1
#      "$((center - diff))" # n_back_2
#      "$((center + 2*diff))" # n_cen_2
#      "32"  # resolution
#      )
#
# python hex.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amor > band_amor.out
# python hex.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crys > band_crys.out
#
# grep tefreqs: band_amor.out > bandte.dat
# python plot_hex.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amortm
#
# grep tefreqs: band_crys.out > bandte.dat
# python plot_hex.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crystm

# %%
# %%bash
# xdg-open temp_epsamor.png

# %%
# %%bash
# source activate mp
#
# # old parameters
# # arr=("167"  # r_air
# #      "140"  # r_cen
# #      "4100" # n_back_amor
# #      "3300" # n_cen_amor
# #      "4100" # n_back_crys
# #      "5100" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # two material:
# arr=("167"  # r_air
#      "180"  # r_cen
#      "4980" # n_back_amor
#      "3578" # n_cen_amor
#      "3887" # n_back_crys
#      "6325" # n_cen_crys
#      "64"  # resolution
#      )
#
# python hex_freq_gap.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amor
# python hex_freq_gap.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crys
# Out:
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      prism, center = (0.333333,0.333333,0)
#           height 1e+20, axis (0,0,1), 6 vertices:
#           (0.222667,0.111333,0)
#           (0.111333,-0.111333,0)
#           (-0.111333,-0.222667,0)
#           (-0.222667,-0.111333,0)
#           (-0.111333,0.111333,0)
#           (0.111333,0.222667,0)
#      prism, center = (0.333333,0,0)
#           height 1e+20, axis (0,0,1), 6 vertices:
#           (0.222667,0.111333,0)
#           (0.111333,-0.111333,0)
#           (-0.111333,-0.222667,0)
#           (-0.222667,-0.111333,0)
#           (-0.111333,0.111333,0)
#           (0.111333,0.222667,0)
# ...
