# %%
# %%bash
#  source activate mp1.8
#
# # old parameter:
# # arr=("167"  # r_air
# #      "140"  # r_cen
# #      "4100" # n_back_amor
# #      "3300" # n_cen_amor
# #      "4100" # n_back_crys
# #      "5100" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # two material:
# # arr=("220"  # r_air
# #      "120"  # r_cen
# #      "4980" # n_back_amor
# #      "3578" # n_cen_amor
# #      "3887" # n_back_crys
# #      "6325" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # do a center frequency and spread!!!!!!!!!
# # one material GST326: 3.578 - 6.325:
# #              GSST:   3.33 - 5.1
# center=4100
# diff=200
# arr=("220"  # r_air
#      "120"  # r_cen
#      "$((center + diff))" # n_back_1
#      "$((center - 2*diff))" # n_cen_1
#      "$((center - diff))" # n_back_2
#      "$((center + 2*diff))" # n_cen_2
#      "64"  # resolution
#      )
#
# python hex.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amor > band_amor.out
# python hex.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crys > band_crys.out
#
# grep tefreqs: band_amor.out > bandte.dat
# python plot_hex.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amortm
#
# grep tefreqs: band_crys.out > bandte.dat
# python plot_hex.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crystm
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# %%bash
# xdg-open temp_epsamor.png

# %%
# %%bash
# source activate mp
#
# # old parameters
# # arr=("167"  # r_air
# #      "140"  # r_cen
# #      "4100" # n_back_amor
# #      "3300" # n_cen_amor
# #      "4100" # n_back_crys
# #      "5100" # n_cen_crys
# #      "64"  # resolution
# #      )
#
# # two material:
# arr=("167"  # r_air
#      "180"  # r_cen
#      "4980" # n_back_amor
#      "3578" # n_cen_amor
#      "3887" # n_back_crys
#      "6325" # n_cen_crys
#      "64"  # resolution
#      )
#
# python hex_freq_gap.py ${arr[0]} ${arr[1]} ${arr[2]} ${arr[3]} ${arr[6]} amor
# python hex_freq_gap.py ${arr[0]} ${arr[1]} ${arr[4]} ${arr[5]} ${arr[6]} crys
# Out:
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
#      prism, center = (0.333333,0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.556,0.444667,-5e+19)
#           (0.444667,0.222,-5e+19)
#           (0.222,0.110667,-5e+19)
#           (0.110667,0.222,-5e+19)
#           (0.222,0.444667,-5e+19)
#           (0.444667,0.556,-5e+19)
#      prism, center = (0.333333,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.556,0.111333,-5e+19)
#           (0.444667,-0.111333,-5e+19)
#           (0.222,-0.222667,-5e+19)
#           (0.110667,-0.111333,-5e+19)
#           (0.222,0.111333,-5e+19)
#           (0.444667,0.222667,-5e+19)
#      prism, center = (0,-0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.222667,-0.222,-5e+19)
#           (0.111333,-0.444667,-5e+19)
#           (-0.111333,-0.556,-5e+19)
#           (-0.222667,-0.444667,-5e+19)
#           (-0.111333,-0.222,-5e+19)
#           (0.111333,-0.110667,-5e+19)
#      prism, center = (-0.333333,-0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.110667,-0.222,-5e+19)
#           (-0.222,-0.444667,-5e+19)
#           (-0.444667,-0.556,-5e+19)
#           (-0.556,-0.444667,-5e+19)
#           (-0.444667,-0.222,-5e+19)
#           (-0.222,-0.110667,-5e+19)
#      prism, center = (-0.333333,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.110667,0.111333,-5e+19)
#           (-0.222,-0.111333,-5e+19)
#           (-0.444667,-0.222667,-5e+19)
#           (-0.556,-0.111333,-5e+19)
#           (-0.444667,0.111333,-5e+19)
#           (-0.222,0.222667,-5e+19)
#      prism, center = (0,0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.222667,0.444667,-5e+19)
#           (0.111333,0.222,-5e+19)
#           (-0.111333,0.110667,-5e+19)
#           (-0.222667,0.222,-5e+19)
#           (-0.111333,0.444667,-5e+19)
#           (0.111333,0.556,-5e+19)
#      cylinder, center = (0,0,0)
#           radius 0.18, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 5 and 43 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8, te band 9, te band 10
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 29 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.584495, 0.644188, 0.699285, 0.803391, 0.817818, 0.838101, 0.876923, 0.942953, 1.0111
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.011712074279785156
# elapsed time for k point: 0.16493701934814453
# total elapsed time for run: 0.1767559051513672
# done
# [0.0, 0.5844954143207188, 0.6441878282104272, 0.6992845709503452, 0.8033909703671895, 0.8178177463491169, 0.8381009908680055, 0.8769233919838831, 0.9429532420232687, 1.0111034254465445]
#
# Elapsed run time = 0.6748 s
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
#      prism, center = (0.333333,0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.556,0.444667,-5e+19)
#           (0.444667,0.222,-5e+19)
#           (0.222,0.110667,-5e+19)
#           (0.110667,0.222,-5e+19)
#           (0.222,0.444667,-5e+19)
#           (0.444667,0.556,-5e+19)
#      prism, center = (0.333333,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.556,0.111333,-5e+19)
#           (0.444667,-0.111333,-5e+19)
#           (0.222,-0.222667,-5e+19)
#           (0.110667,-0.111333,-5e+19)
#           (0.222,0.111333,-5e+19)
#           (0.444667,0.222667,-5e+19)
#      prism, center = (0,-0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.222667,-0.222,-5e+19)
#           (0.111333,-0.444667,-5e+19)
#           (-0.111333,-0.556,-5e+19)
#           (-0.222667,-0.444667,-5e+19)
#           (-0.111333,-0.222,-5e+19)
#           (0.111333,-0.110667,-5e+19)
#      prism, center = (-0.333333,-0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.110667,-0.222,-5e+19)
#           (-0.222,-0.444667,-5e+19)
#           (-0.444667,-0.556,-5e+19)
#           (-0.556,-0.444667,-5e+19)
#           (-0.444667,-0.222,-5e+19)
#           (-0.222,-0.110667,-5e+19)
#      prism, center = (-0.333333,0,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (-0.110667,0.111333,-5e+19)
#           (-0.222,-0.111333,-5e+19)
#           (-0.444667,-0.222667,-5e+19)
#           (-0.556,-0.111333,-5e+19)
#           (-0.444667,0.111333,-5e+19)
#           (-0.222,0.222667,-5e+19)
#      prism, center = (0,0.333333,0)
#           height 1e+20, axis (0,0,1), sidewall angle: 0 radians, 6 vertices:
#           (0.222667,0.444667,-5e+19)
#           (0.111333,0.222,-5e+19)
#           (-0.111333,0.110667,-5e+19)
#           (-0.222667,0.222,-5e+19)
#           (-0.111333,0.444667,-5e+19)
#           (0.111333,0.556,-5e+19)
#      cylinder, center = (0,0,0)
#           radius 0.18, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 5 and 43 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8, te band 9, te band 10
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 58 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.346478, 0.523263, 0.5237, 0.707971, 0.708908, 0.762144, 0.787808, 0.866564, 0.867861
# 1 k-points
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.011425971984863281
# elapsed time for k point: 0.3668501377105713
# total elapsed time for run: 0.3783853054046631
# done
# [0.0, 0.3464782312027598, 0.5232630555398742, 0.5237000079439526, 0.7079714020136872, 0.7089079525642706, 0.7621437597822959, 0.7878078219097145, 0.8665642522093798, 0.8678610429625189]
#
# Elapsed run time = 0.9291 s
